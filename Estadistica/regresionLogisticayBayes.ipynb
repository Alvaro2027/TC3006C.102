# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn

# %%
df=pd.read_csv('/content/Social_Network_Ads.csv')

# %%
df.head()

# %%
df.isnull().sum()

# %%
#filtrar base de datos en compradores y no compradores
c=df[df.Purchased==1]
nc=df[df.Purchased==0]

# %%
plt.title('consumidores y no consumidores')
plt.xlabel('Edad')
plt.ylabel('Salario')
plt.scatter(nc.Age, nc.EstimatedSalary, color='red', label='No consumidor', alpha=0.5)#tono de color alpha
plt.scatter(c.Age, c.EstimatedSalary, color='blue', label='consumidor', alpha=0.5)
plt.legend()
plt.show()

# %%
x=df.iloc[:len(df),[2,3]].values
y=df.iloc[:len(df),-1]
#variables regreserosa y independientes

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split(x,y,test_size=0.2, random_state=42)
#dividir datos de prueba y entrenamiento

# %%
#escalar los datos entre 0 y 1
from sklearn.preprocessing import StandardScaler
sc_X=StandardScaler()
x_train=sc_X.fit_transform(x_train)
x_test=sc_X.transform(x_test)

# %%
from numpy.random.mtrand import logistic
from sklearn.linear_model import LogisticRegression
logistic= LogisticRegression()
logistic.fit(x_train,y_train)
y_predict=logistic.predict(x_test)

# %%
x_test

# %%
y_test

# %%
import statsmodels.api as sm
x_train=sm.add_constant(x_train)
modelo= sm.Logit(endog=y_train, exog=x_train)
modelo= modelo.fit()
print(modelo.summary())

# %% [markdown]
# ### BAYES

# %%
df.head()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(df.iloc[:,[2,3]],df.iloc[:,-1], test_size=0.2, random_state=42)

# %%
from sklearn.naive_bayes import GaussianNB
nb=GaussianNB()
nb.fit(x_train, y_train)

# %%
y_pred=nb.predict(x_test)
print(y_pred)

# %%
print("exactitud del modelo", nb.score(x_test,y_test))

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred)

# %%
clf = make_pipeline(StandardScaler(), LogisticRegression(random_state=0))
clf.fit(x_train, y_train)

# %%
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix

cm = confusion_matrix(y_test, y_pred)

cm_display = ConfusionMatrixDisplay(cm).plot()
